# %% [markdown]
# # Avacado Project

# %% [markdown]
# We can Find which region has the Most Avacado Produced and what is its average price .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_avo=pd.read_csv("Avocado.csv")
df_avo

# %%
df_avo.head()

# %%
df_avo.tail()

# %% [markdown]
# Here we have found That it has Null Values in the bottom. We need to remove nulls from the data set to make it clean.

# %%
df_avo.shape

# %% [markdown]
# Now We Can change the Name of Column name as per our suitablity

# %%
df1_avo=df_avo.rename(columns={'4046':'PLU 4046 sold','4225':'PLU 4225 sold','4770':'PLU 4770 sold','type':'Type','year':'Year','region':'Region'})

# %%
df1_avo
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume  PLU 4046 sold  \
# 0             0.0  27-12-2015          1.33      64236.62        1036.74
# 1             1.0  20-12-2015          1.35      54876.98         674.28
# 2             2.0  13-12-2015          0.93     118220.22         794.70
# 3             3.0  06-12-2015          1.08      78992.15        1132.00
# 4             4.0  29-11-2015          1.28      51039.60         941.48
# ...           ...         ...           ...           ...            ...
# 16463         NaN         NaN           NaN           NaN            NaN
# 16464         NaN         NaN           NaN           NaN            NaN
# 16465         NaN         NaN           NaN           NaN            NaN
# 16466         NaN         NaN           NaN           NaN            NaN
# 16467         NaN         NaN           NaN           NaN            NaN
#
#        PLU 4225 sold  PLU 4770 sold  Total Bags  Small Bags  Large Bags  \
# ...

# %%
df1_avo.dtypes
# Out:
# Unnamed: 0       float64
# Date              object
# AveragePrice     float64
# Total Volume     float64
# PLU 4046 sold    float64
# PLU 4225 sold    float64
# PLU 4770 sold    float64
# Total Bags       float64
# Small Bags       float64
# Large Bags       float64
# XLarge Bags      float64
# Type              object
# Year             float64
# Region            object
# dtype: object

# %%
df1_avo.columns

# %%
df1_avo.convert_dtypes().dtypes

# %% [markdown]
# this will Convert the Data type n to best suited Data type

# %%
df1_avo.info()

# %%
df1_avo.describe()
# Out:
#         Unnamed: 0  AveragePrice  Total Volume  PLU 4046 sold  PLU 4225 sold  \
# count  1517.000000   1517.000000  1.517000e+03   1.517000e+03   1.517000e+03
# mean     26.995386      1.074990  1.601879e+06   6.464387e+05   6.114375e+05
# std      14.848287      0.188891  4.433143e+06   1.947614e+06   1.672906e+06
# min       0.000000      0.490000  3.875074e+04   4.677200e+02   1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05   2.040034e+04   4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05   8.175117e+04   1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05   3.775785e+05   4.851503e+05
# max      51.000000      1.680000  4.465546e+07   1.893304e+07   1.895648e+07
#
#        PLU 4770 sold    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count   1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean    5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# ...

# %% [markdown]
# Mean and Meadian Check shows there are much differences in Total Volume,4046,4225,Total Bags, Small bags , Large Bags column

# %%
df1_avo.isnull()

# %% [markdown]
# We have Null Values in the Data sets

# %%
df=df1_avo.dropna()

# %%
df

# %%
df.shape

# %%
df1_avo.shape

# %% [markdown]
# Here we have dropped the NA Values from our Dataset

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# Data set has no missing values .

# %%
dfcor=df.corr(method='pearson')

# %%
dfcor
# Out:
#                Unnamed: 0  AveragePrice  Total Volume  PLU 4046 sold  \
# Unnamed: 0       1.000000     -0.075531      0.091934       0.092013
# AveragePrice    -0.075531      1.000000     -0.140470      -0.190096
# Total Volume     0.091934     -0.140470      1.000000       0.985568
# PLU 4046 sold    0.092013     -0.190096      0.985568       1.000000
# PLU 4225 sold    0.093566     -0.092084      0.987154       0.951952
# PLU 4770 sold    0.075647     -0.100567      0.934347       0.898570
# Total Bags       0.081007     -0.111597      0.967689       0.930395
# Small Bags       0.083485     -0.097682      0.960642       0.922278
# Large Bags       0.065364     -0.177480      0.910226       0.884229
# XLarge Bags     -0.050993     -0.048284      0.521717       0.474063
# Year            -0.012854      0.178683     -0.004189      -0.040439
#
#                PLU 4225 sold  PLU 4770 sold  Total Bags  Small Bags  \
# Unnamed: 0          0.093566       0.075647    0.081007    0.083485
# ...

# %%
sns.heatmap(dfcor)

# %%
sns.pairplot(df)

# %%
dfcor.columns

# %%
df['Unnamed: 0'].plot.box()

# %%
df['AveragePrice'].plot.box()

# %%
df['AveragePrice'].plot.box()

# %%
collist=dfcor.columns.values
ncol=14
nrows=10
collist

# %% [markdown]
# Outliers are present in Average Values

# %%
plt.figure(figsize=(ncol,5*ncol))
for i in range(0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(dfcor[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# We Can conclude that Outliers are presnent in Unnamed :0 ,Average Price,and very few in Year Column

# %% [markdown]
# Now we can check for skewness in the Data set.

# %%
plt.figure(figsize=(30,30))
for i in range(0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(dfcor[collist[i]])

# %% [markdown]
# We Can observe that only XLarge Bag column has a normal distribution,

# %%
sns.pairplot(dfcor)

# %% [markdown]
# Now removing outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(dfcor))
z

# %%
threshold=3
print(np.where(z>3))

# %%
df_new=dfcor[(z<3).all(axis=1)]

# %%
df_new
# Out:
#                Unnamed: 0  AveragePrice  Total Volume  PLU 4046 sold  \
# Total Volume     0.091934     -0.140470      1.000000       0.985568
# PLU 4046 sold    0.092013     -0.190096      0.985568       1.000000
# PLU 4225 sold    0.093566     -0.092084      0.987154       0.951952
# PLU 4770 sold    0.075647     -0.100567      0.934347       0.898570
# Total Bags       0.081007     -0.111597      0.967689       0.930395
# Small Bags       0.083485     -0.097682      0.960642       0.922278
# Large Bags       0.065364     -0.177480      0.910226       0.884229
# XLarge Bags     -0.050993     -0.048284      0.521717       0.474063
#
#                PLU 4225 sold  PLU 4770 sold  Total Bags  Small Bags  \
# Total Volume        0.987154       0.934347    0.967689    0.960642
# PLU 4046 sold       0.951952       0.898570    0.930395    0.922278
# PLU 4225 sold       1.000000       0.927757    0.951779    0.943988
# PLU 4770 sold       0.927757       1.000000    0.926405    0.923607
# ...

# %%
df_newavo=df_new.drop(['Unnamed: 0','Year'],axis=1)

# %% [markdown]
# Now we can Drop Unnamed and Year Column to make data Clean and make a new Data frame to conclude

# %%
df_newavo
# Out:
#                AveragePrice  Total Volume  PLU 4046 sold  PLU 4225 sold  \
# Total Volume      -0.140470      1.000000       0.985568       0.987154
# PLU 4046 sold     -0.190096      0.985568       1.000000       0.951952
# PLU 4225 sold     -0.092084      0.987154       0.951952       1.000000
# PLU 4770 sold     -0.100567      0.934347       0.898570       0.927757
# Total Bags        -0.111597      0.967689       0.930395       0.951779
# Small Bags        -0.097682      0.960642       0.922278       0.943988
# Large Bags        -0.177480      0.910226       0.884229       0.900496
# XLarge Bags       -0.048284      0.521717       0.474063       0.504718
#
#                PLU 4770 sold  Total Bags  Small Bags  Large Bags  XLarge Bags
# Total Volume        0.934347    0.967689    0.960642    0.910226     0.521717
# PLU 4046 sold       0.898570    0.930395    0.922278    0.884229     0.474063
# PLU 4225 sold       0.927757    0.951779    0.943988    0.900496     0.504718
# ...

# %%
#Now we devide the Data into input and output
df_x=df_newavo.drop(columns=["AveragePrice"])
y=df_newavo[["AveragePrice"]]

# %% [markdown]
# 3 Rows are deleted as a outliers

# %%
df_x
# Out:
#                Total Volume  PLU 4046 sold  PLU 4225 sold  PLU 4770 sold  \
# Total Volume       1.000000       0.985568       0.987154       0.934347
# PLU 4046 sold      0.985568       1.000000       0.951952       0.898570
# PLU 4225 sold      0.987154       0.951952       1.000000       0.927757
# PLU 4770 sold      0.934347       0.898570       0.927757       1.000000
# Total Bags         0.967689       0.930395       0.951779       0.926405
# Small Bags         0.960642       0.922278       0.943988       0.923607
# Large Bags         0.910226       0.884229       0.900496       0.840523
# XLarge Bags        0.521717       0.474063       0.504718       0.646053
#
#                Total Bags  Small Bags  Large Bags  XLarge Bags
# Total Volume     0.967689    0.960642    0.910226     0.521717
# PLU 4046 sold    0.930395    0.922278    0.884229     0.474063
# PLU 4225 sold    0.951779    0.943988    0.900496     0.504718
# ...

# %%
y
# Out:
#                AveragePrice
# Total Volume      -0.140470
# PLU 4046 sold     -0.190096
# PLU 4225 sold     -0.092084
# PLU 4770 sold     -0.100567
# Total Bags        -0.111597
# Small Bags        -0.097682
# Large Bags        -0.177480
# XLarge Bags       -0.048284

# %%
#Lets do the preprocessing bring features to common scale
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(df_x)
x=sc.transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
#Lets convert the target variable into integers
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit(y)
y=le.transform(y)
y
# Out:
# array([2, 0, 6, 4, 3, 5, 1, 7], dtype=int64)

# %%
#Lets save this model using joblib
import joblib 
  
# Save the model as a pickle in a file 
joblib.dump(df_newavo, "Avacodo.pkl")
# Out:
# ['Avacodo.pkl']
