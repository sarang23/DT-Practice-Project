# %% [markdown]
# # Happiness Project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_happy=pd.read_csv("happiness.csv")
df_happy
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df_happy .columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df_happy.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df_happy.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# As there are no Null Values so we perform EDA straight away.

# %% [markdown]
# # EDA

# %% [markdown]
# Scatter Plot

# %%
import seaborn as sns

# %%
sns.scatterplot(x="Happiness Rank",y="Happiness Score",data=df_happy)

# %% [markdown]
# Showing Neagtive Correlation

# %%
sns.scatterplot(x="Standard Error",y="Happiness Score",data=df_happy)

# %%
sns.scatterplot(x="Economy (GDP per Capita)",y="Happiness Score",data=df_happy)

# %% [markdown]
# Showing Positive Correlation

# %%
sns.scatterplot(x="Family",y="Happiness Score",data=df_happy)

# %%
sns.scatterplot(x="Health (Life Expectancy)",y="Happiness Score",data=df_happy)

# %%
sns.scatterplot(x="Freedom",y="Happiness Score",data=df_happy)

# %%
sns.scatterplot(x="Trust (Government Corruption)",y="Happiness Score",data=df_happy)

# %%
sns.scatterplot(x="Generosity",y="Happiness Score",data=df_happy)

# %%
sns.scatterplot(x="Dystopia Residual",y="Happiness Score",data=df_happy)

# %%
import matplotlib.pyplot as plt 
from pandas.plotting import scatter_matrix

# %%
features=['Country', 'Region', 'Happiness Rank', 'Happiness Score',
       'Standard Error', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity', 'Dystopia Residual']

# %%
scatter_matrix(df_happy[features],alpha=1, figsize=(40,20), ax=None, grid=False, diagonal='hist', marker='.', density_kwds=None, hist_kwds=None, range_padding=0.05)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F184659610>,
# ...
#       dtype=object)

# %%
df_happy.corr().round(2)
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                           1.00            -0.99
# Happiness Score                         -0.99             1.00
# Standard Error                           0.16            -0.18
# Economy (GDP per Capita)                -0.79             0.78
# Family                                  -0.73             0.74
# Health (Life Expectancy)                -0.74             0.72
# Freedom                                 -0.56             0.57
# Trust (Government Corruption)           -0.37             0.40
# Generosity                              -0.16             0.18
# Dystopia Residual                       -0.52             0.53
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                           0.16                     -0.79
# Happiness Score                         -0.18                      0.78
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df_happy.corr().round(2),annot=True,linewidth=1,linecolor="black",fmt='10')

# %%
df_happy.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# Happiness Score is mostly dependent on 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)'

# %%
df_happy.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df_happy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
import joblib
joblib.dump(df_happy,"happiness.pkl")
# Out:
# ['happiness.pkl']
