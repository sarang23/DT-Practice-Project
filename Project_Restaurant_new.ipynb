# %% [markdown]
# # Predicting Restaurant Food Cost

# %%
#Aim of project is to predict the cost of the food served by the restaurants across different cities in India

# %%
import pandas as pd
df_train=pd.read_excel("Data_Food_Train.xlsx")
df_train["source"]="train"
df_test=pd.read_excel("Data_Food_Test.xlsx")
df_test["source"]="test"
df_food=pd.concat([df_train,df_test])
df_food
# Out:
#                   TITLE  RESTAURANT_ID  \
# 0         CASUAL DINING           9438
# 1     CASUAL DINING,BAR          13198
# 2         CASUAL DINING          10915
# 3           QUICK BITES           6346
# 4        DESSERT PARLOR          15387
# ...                 ...            ...
# 4226      CASUAL DINING           9057
# 4227               None           1247
# 4228        QUICK BITES           8617
# 4229        QUICK BITES           6485
# 4230        QUICK BITES           2421
#
#                                            CUISINES  \
# 0                       Malwani, Goan, North Indian
# 1                    Asian, Modern Indian, Japanese
# 2        North Indian, Chinese, Biryani, Hyderabadi
# 3                                  Tibetan, Chinese
# 4                                          Desserts
# ...                                             ...
# 4226                 North Indian, Mughlai, Chinese
# 4227  Biryani, North Indian, Sandwich, Salad, Wraps
# 4228                      Continental, North Indian
# 4229                               Rolls, Beverages
# 4230                                        Mughlai
#
#                                                    TIME         CITY  \
# 0                11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)        Thane
# 1                                  6pm – 11pm (Mon-Sun)      Chennai
# 2                   11am – 3:30pm, 7pm – 11pm (Mon-Sun)      Chennai
# 3                               11:30am – 1am (Mon-Sun)       Mumbai
# 4                                  11am – 1am (Mon-Sun)       Mumbai
# ...                                                 ...          ...
# 4226                        11:30am – 11:30pm (Mon-Sun)    New Delhi
# 4227                               11am – 1am (Mon-Sun)    Bangalore
# 4228                         9:30am – 10:30pm (Mon-Sun)    Faridabad
# 4229  11am – 11:30pm (Mon, Tue, Wed, Thu, Sat, Sun),...        Kochi
# 4230                                5pm – 1am (Mon-Sun)  Bandra West
#
#               LOCALITY RATING      VOTES    COST source
# 0       Dombivali East    3.6   49 votes  1200.0  train
# 1            Ramapuram    4.2   30 votes  1500.0  train
# 2           Saligramam    3.8  221 votes   800.0  train
# 3          Bandra West    4.1   24 votes   800.0  train
# 4          Lower Parel    3.8  165 votes   300.0  train
# ...                ...    ...        ...     ...    ...
# 4226      Punjabi Bagh    3.9  287 votes     NaN   test
# 4227        HSR Layout    4.3  469 votes     NaN   test
# 4228         Sector 86    3.7   53 votes     NaN   test
# 4229             Kochi      -        NaN     NaN   test
# 4230  Perry Cross Road    3.7   63 votes     NaN   test
#
# [16921 rows x 10 columns]

# %%
#shape of data set
df_food.shape
# Out:
# (16921, 10)

# %%
# We have found in the Dataset is not indexed.#chceking the datatypes
df_food.dtypes
#Reseting the index
df_food.reset_index(drop=True,inplace=True)
df_food
# Out:
#                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 16916      CASUAL DINING           9057
# 16917               None           1247
# 16918        QUICK BITES           8617
# 16919        QUICK BITES           6485
# 16920        QUICK BITES           2421
#
#                                             CUISINES  \
# 0                        Malwani, Goan, North Indian
# 1                     Asian, Modern Indian, Japanese
# 2         North Indian, Chinese, Biryani, Hyderabadi
# 3                                   Tibetan, Chinese
# 4                                           Desserts
# ...                                              ...
# 16916                 North Indian, Mughlai, Chinese
# 16917  Biryani, North Indian, Sandwich, Salad, Wraps
# 16918                      Continental, North Indian
# 16919                               Rolls, Beverages
# 16920                                        Mughlai
#
#                                                     TIME         CITY  \
# 0                 11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)        Thane
# 1                                   6pm – 11pm (Mon-Sun)      Chennai
# 2                    11am – 3:30pm, 7pm – 11pm (Mon-Sun)      Chennai
# 3                                11:30am – 1am (Mon-Sun)       Mumbai
# 4                                   11am – 1am (Mon-Sun)       Mumbai
# ...                                                  ...          ...
# 16916                        11:30am – 11:30pm (Mon-Sun)    New Delhi
# 16917                               11am – 1am (Mon-Sun)    Bangalore
# 16918                         9:30am – 10:30pm (Mon-Sun)    Faridabad
# 16919  11am – 11:30pm (Mon, Tue, Wed, Thu, Sat, Sun),...        Kochi
# 16920                                5pm – 1am (Mon-Sun)  Bandra West
#
#                LOCALITY RATING      VOTES    COST source
# 0        Dombivali East    3.6   49 votes  1200.0  train
# 1             Ramapuram    4.2   30 votes  1500.0  train
# 2            Saligramam    3.8  221 votes   800.0  train
# 3           Bandra West    4.1   24 votes   800.0  train
# 4           Lower Parel    3.8  165 votes   300.0  train
# ...                 ...    ...        ...     ...    ...
# 16916      Punjabi Bagh    3.9  287 votes     NaN   test
# 16917        HSR Layout    4.3  469 votes     NaN   test
# 16918         Sector 86    3.7   53 votes     NaN   test
# 16919             Kochi      -        NaN     NaN   test
# 16920  Perry Cross Road    3.7   63 votes     NaN   test
#
# [16921 rows x 10 columns]

# %%
#chceking the datatypes
df_food.dtypes
# Out:
# TITLE             object
# RESTAURANT_ID      int64
# CUISINES          object
# TIME              object
# CITY              object
# LOCALITY          object
# RATING            object
# VOTES             object
# COST             float64
# source            object
# dtype: object

# %%
#Lets chcek null values
df_food.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY              147
# LOCALITY          128
# RATING              4
# VOTES            1606
# COST             4231
# source              0
# dtype: int64

# %%
#Imputing missing cells in votes column
df_food["VOTES"].fillna(0,inplace=True)

# %%
df_food.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY              147
# LOCALITY          128
# RATING              4
# VOTES               0
# COST             4231
# source              0
# dtype: int64

# %%
#chceking value counts for "RATING"
df_food["RATING"].value_counts()
# Out:
# 3.9    1643
# 3.8    1604
# 4.0    1498
# 3.7    1437
# 3.6    1261
# 4.1    1217
# 3.5     988
# 4.2     968
# NEW     930
# 3.4     777
# 4.3     740
# -       672
# 3.3     485
# 4.4     484
# 3.2     349
# 4.5     274
# 3.1     263
# 2.9     242
# 3.0     229
# 2.8     191
# 4.6     184
# 2.7     129
# 4.7      90
# 2.6      85
# 2.5      51
# 4.8      49
# 4.9      28
# 2.4      24
# 2.3      15
# 2.1       4
# 2.2       4
# 2.0       2
# Name: RATING, dtype: int64

# %%
df_food
# Out:
#                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 16916      CASUAL DINING           9057
# 16917               None           1247
# 16918        QUICK BITES           8617
# 16919        QUICK BITES           6485
# 16920        QUICK BITES           2421
#
#                                             CUISINES  \
# 0                        Malwani, Goan, North Indian
# 1                     Asian, Modern Indian, Japanese
# 2         North Indian, Chinese, Biryani, Hyderabadi
# 3                                   Tibetan, Chinese
# 4                                           Desserts
# ...                                              ...
# 16916                 North Indian, Mughlai, Chinese
# 16917  Biryani, North Indian, Sandwich, Salad, Wraps
# 16918                      Continental, North Indian
# 16919                               Rolls, Beverages
# 16920                                        Mughlai
#
#                                                     TIME         CITY  \
# 0                 11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)        Thane
# 1                                   6pm – 11pm (Mon-Sun)      Chennai
# 2                    11am – 3:30pm, 7pm – 11pm (Mon-Sun)      Chennai
# 3                                11:30am – 1am (Mon-Sun)       Mumbai
# 4                                   11am – 1am (Mon-Sun)       Mumbai
# ...                                                  ...          ...
# 16916                        11:30am – 11:30pm (Mon-Sun)    New Delhi
# 16917                               11am – 1am (Mon-Sun)    Bangalore
# 16918                         9:30am – 10:30pm (Mon-Sun)    Faridabad
# 16919  11am – 11:30pm (Mon, Tue, Wed, Thu, Sat, Sun),...        Kochi
# 16920                                5pm – 1am (Mon-Sun)  Bandra West
#
#                LOCALITY RATING      VOTES    COST source
# 0        Dombivali East    3.6   49 votes  1200.0  train
# 1             Ramapuram    4.2   30 votes  1500.0  train
# 2            Saligramam    3.8  221 votes   800.0  train
# 3           Bandra West    4.1   24 votes   800.0  train
# 4           Lower Parel    3.8  165 votes   300.0  train
# ...                 ...    ...        ...     ...    ...
# 16916      Punjabi Bagh    3.9  287 votes     NaN   test
# 16917        HSR Layout    4.3  469 votes     NaN   test
# 16918         Sector 86    3.7   53 votes     NaN   test
# 16919             Kochi      -          0     NaN   test
# 16920  Perry Cross Road    3.7   63 votes     NaN   test
#
# [16921 rows x 10 columns]

# %%
df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16921 entries, 0 to 16920
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TITLE          16921 non-null  object
#  1   RESTAURANT_ID  16921 non-null  int64
#  2   CUISINES       16921 non-null  object
#  3   TIME           16921 non-null  object
#  4   CITY           16774 non-null  object
#  5   LOCALITY       16793 non-null  object
#  6   RATING         16917 non-null  object
#  7   VOTES          16921 non-null  object
#  8   COST           12690 non-null  float64
#  9   source         16921 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.3+ MB

# %%
#Replacing New, - and 0 values to 0 in Ratings table and Can change Data type to float
df_food["RATING"].replace("NEW",0,inplace=True)
df_food["RATING"].replace("-",0,inplace=True)
df_food["RATING"].fillna(0,inplace=True)
df_food["RATING"]=df_food["RATING"].astype(float)

# %%
df_food.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY              147
# LOCALITY          128
# RATING              0
# VOTES               0
# COST             4231
# source              0
# dtype: int64

# %%
df_food["VOTES"]=df_food["VOTES"].str.strip(" votes")

# %%
df_food
# Out:
#                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 16916      CASUAL DINING           9057
# 16917               None           1247
# 16918        QUICK BITES           8617
# 16919        QUICK BITES           6485
# 16920        QUICK BITES           2421
#
#                                             CUISINES  \
# 0                        Malwani, Goan, North Indian
# 1                     Asian, Modern Indian, Japanese
# 2         North Indian, Chinese, Biryani, Hyderabadi
# 3                                   Tibetan, Chinese
# 4                                           Desserts
# ...                                              ...
# 16916                 North Indian, Mughlai, Chinese
# 16917  Biryani, North Indian, Sandwich, Salad, Wraps
# 16918                      Continental, North Indian
# 16919                               Rolls, Beverages
# 16920                                        Mughlai
#
#                                                     TIME         CITY  \
# 0                 11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)        Thane
# 1                                   6pm – 11pm (Mon-Sun)      Chennai
# 2                    11am – 3:30pm, 7pm – 11pm (Mon-Sun)      Chennai
# 3                                11:30am – 1am (Mon-Sun)       Mumbai
# 4                                   11am – 1am (Mon-Sun)       Mumbai
# ...                                                  ...          ...
# 16916                        11:30am – 11:30pm (Mon-Sun)    New Delhi
# 16917                               11am – 1am (Mon-Sun)    Bangalore
# 16918                         9:30am – 10:30pm (Mon-Sun)    Faridabad
# 16919  11am – 11:30pm (Mon, Tue, Wed, Thu, Sat, Sun),...        Kochi
# 16920                                5pm – 1am (Mon-Sun)  Bandra West
#
#                LOCALITY  RATING VOTES    COST source
# 0        Dombivali East     3.6    49  1200.0  train
# 1             Ramapuram     4.2    30  1500.0  train
# 2            Saligramam     3.8   221   800.0  train
# 3           Bandra West     4.1    24   800.0  train
# 4           Lower Parel     3.8   165   300.0  train
# ...                 ...     ...   ...     ...    ...
# 16916      Punjabi Bagh     3.9   287     NaN   test
# 16917        HSR Layout     4.3   469     NaN   test
# 16918         Sector 86     3.7    53     NaN   test
# 16919             Kochi     0.0   NaN     NaN   test
# 16920  Perry Cross Road     3.7    63     NaN   test
#
# [16921 rows x 10 columns]

# %%
df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16921 entries, 0 to 16920
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TITLE          16921 non-null  object
#  1   RESTAURANT_ID  16921 non-null  int64
#  2   CUISINES       16921 non-null  object
#  3   TIME           16921 non-null  object
#  4   CITY           16774 non-null  object
#  5   LOCALITY       16793 non-null  object
#  6   RATING         16921 non-null  float64
#  7   VOTES          15315 non-null  object
#  8   COST           12690 non-null  float64
#  9   source         16921 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
df_food["VOTES"]=df_food["VOTES"].astype(float)

# %%
df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16921 entries, 0 to 16920
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TITLE          16921 non-null  object
#  1   RESTAURANT_ID  16921 non-null  int64
#  2   CUISINES       16921 non-null  object
#  3   TIME           16921 non-null  object
#  4   CITY           16774 non-null  object
#  5   LOCALITY       16793 non-null  object
#  6   RATING         16921 non-null  float64
#  7   VOTES          15315 non-null  float64
#  8   COST           12690 non-null  float64
#  9   source         16921 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 1.3+ MB

# %%
df_food.loc[df_food["CITY"].isnull()]
# Out:
#                    TITLE  RESTAURANT_ID  \
# 129                 None           9101
# 246          QUICK BITES          14502
# 411                 None           6313
# 466                 None           1133
# 481                 None           4788
# ...                  ...            ...
# 16311  PUB,CASUAL DINING           9779
# 16313      CASUAL DINING           5922
# 16803               None           4748
# 16815        QUICK BITES           8587
# 16857        QUICK BITES          12015
#
#                                                CUISINES  \
# 129    North Indian, South Indian, Chinese, Continental
# 246                                             Biryani
# 411     North Indian, Chinese, Pizza, Burger, Fast Food
# 466                                        North Indian
# 481                                         Street Food
# ...                                                 ...
# 16311                    Continental, Mexican, American
# 16313      North Indian, South Indian, Chinese, Biryani
# 16803               Fast Food, Italian, Pizza, Sandwich
# 16815                             Chinese, North Indian
# 16857                                          Lebanese
#
#                                                    TIME CITY  \
# 129                   12noon – 3pm, 7pm – 2am (Mon-Sun)  NaN
# 246                             12noon – 11pm (Mon-Sun)  NaN
# 411                                 7pm – 4am (Mon-Sun)  NaN
# 466                                 4pm – 9pm (Mon-Sun)  NaN
# 481     11am – 11pm (Mon),9:30am – 12midnight (Tue-Sun)  NaN
# ...                                                 ...  ...
# 16311                            5pm – 1:30am (Mon-Sun)  NaN
# 16313                           6am – 11:30pm (Mon-Sun)  NaN
# 16803                               1pm – 8am (Mon-Sun)  NaN
# 16815  11:45am – 3:30pm, 7:30pm – 11:40pm (Mon, Sat)...  NaN
# 16857                              4pm – 11pm (Mon-Sun)  NaN
#
#                  LOCALITY  RATING   VOTES   COST source
# 129                   NaN     3.6   728.0  500.0  train
# 246    Palarivattom Kochi     3.4    82.0  300.0  train
# 411                   NaN     4.0    29.0  600.0  train
# 466                   NaN     4.2    55.0  200.0  train
# 481                   NaN     3.7   616.0  250.0  train
# ...                   ...     ...     ...    ...    ...
# 16311  Maharashtra 400013     4.0  1142.0    NaN   test
# 16313                 NaN     3.5   102.0    NaN   test
# 16803                 NaN     3.7    27.0    NaN   test
# 16815                 NaN     3.5    25.0    NaN   test
# 16857             Chennai     3.7   124.0    NaN   test
#
# [147 rows x 10 columns]

# %%
#We can replace all Nan Vales to unknown in both the columns.
df_food['CITY'].fillna("Unknown",inplace=True)
df_food['LOCALITY'].fillna("Unknown",inplace=True)

# %%
df_food
# Out:
#                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 16916      CASUAL DINING           9057
# 16917               None           1247
# 16918        QUICK BITES           8617
# 16919        QUICK BITES           6485
# 16920        QUICK BITES           2421
#
#                                             CUISINES  \
# 0                        Malwani, Goan, North Indian
# 1                     Asian, Modern Indian, Japanese
# 2         North Indian, Chinese, Biryani, Hyderabadi
# 3                                   Tibetan, Chinese
# 4                                           Desserts
# ...                                              ...
# 16916                 North Indian, Mughlai, Chinese
# 16917  Biryani, North Indian, Sandwich, Salad, Wraps
# 16918                      Continental, North Indian
# 16919                               Rolls, Beverages
# 16920                                        Mughlai
#
#                                                     TIME         CITY  \
# 0                 11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)        Thane
# 1                                   6pm – 11pm (Mon-Sun)      Chennai
# 2                    11am – 3:30pm, 7pm – 11pm (Mon-Sun)      Chennai
# 3                                11:30am – 1am (Mon-Sun)       Mumbai
# 4                                   11am – 1am (Mon-Sun)       Mumbai
# ...                                                  ...          ...
# 16916                        11:30am – 11:30pm (Mon-Sun)    New Delhi
# 16917                               11am – 1am (Mon-Sun)    Bangalore
# 16918                         9:30am – 10:30pm (Mon-Sun)    Faridabad
# 16919  11am – 11:30pm (Mon, Tue, Wed, Thu, Sat, Sun),...        Kochi
# 16920                                5pm – 1am (Mon-Sun)  Bandra West
#
#                LOCALITY  RATING  VOTES    COST source
# 0        Dombivali East     3.6   49.0  1200.0  train
# 1             Ramapuram     4.2   30.0  1500.0  train
# 2            Saligramam     3.8  221.0   800.0  train
# 3           Bandra West     4.1   24.0   800.0  train
# 4           Lower Parel     3.8  165.0   300.0  train
# ...                 ...     ...    ...     ...    ...
# 16916      Punjabi Bagh     3.9  287.0     NaN   test
# 16917        HSR Layout     4.3  469.0     NaN   test
# 16918         Sector 86     3.7   53.0     NaN   test
# 16919             Kochi     0.0    NaN     NaN   test
# 16920  Perry Cross Road     3.7   63.0     NaN   test
#
# [16921 rows x 10 columns]

# %%
# Check for Null Values
df_food.loc[df_food["CITY"].isnull()]
# Out:
# Empty DataFrame
# Columns: [TITLE, RESTAURANT_ID, CUISINES, TIME, CITY, LOCALITY, RATING, VOTES, COST, source]
# Index: []

# %%
df_food.loc[df_food["LOCALITY"].isnull()]
# Out:
# Empty DataFrame
# Columns: [TITLE, RESTAURANT_ID, CUISINES, TIME, CITY, LOCALITY, RATING, VOTES, COST, source]
# Index: []

# %%
df_food.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY                0
# LOCALITY            0
# RATING              0
# VOTES            1606
# COST             4231
# source              0
# dtype: int64

# %%
df_food.describe
# Out:
# <bound method NDFrame.describe of                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 16916      CASUAL DINING           9057
# 16917               None           1247
# 16918        QUICK BITES           8617
# 16919        QUICK BITES           6485
# 16920        QUICK BITES           2421
#
#                                             CUISINES  \
# 0                        Malwani, Goan, North Indian
# 1                     Asian, Modern Indian, Japanese
# 2         North Indian, Chinese, Biryani, Hyderabadi
# 3                                   Tibetan, Chinese
# 4                                           Desserts
# ...                                              ...
# 16916                 North Indian, Mughlai, Chinese
# 16917  Biryani, North Indian, Sandwich, Salad, Wraps
# 16918                      Continental, North Indian
# 16919                               Rolls, Beverages
# 16920                                        Mughlai
#
#                                                     TIME         CITY  \
# 0                 11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)        Thane
# 1                                   6pm – 11pm (Mon-Sun)      Chennai
# 2                    11am – 3:30pm, 7pm – 11pm (Mon-Sun)      Chennai
# 3                                11:30am – 1am (Mon-Sun)       Mumbai
# 4                                   11am – 1am (Mon-Sun)       Mumbai
# ...                                                  ...          ...
# 16916                        11:30am – 11:30pm (Mon-Sun)    New Delhi
# 16917                               11am – 1am (Mon-Sun)    Bangalore
# 16918                         9:30am – 10:30pm (Mon-Sun)    Faridabad
# 16919  11am – 11:30pm (Mon, Tue, Wed, Thu, Sat, Sun),...        Kochi
# 16920                                5pm – 1am (Mon-Sun)  Bandra West
#
#                LOCALITY  RATING  VOTES    COST source
# 0        Dombivali East     3.6   49.0  1200.0  train
# 1             Ramapuram     4.2   30.0  1500.0  train
# 2            Saligramam     3.8  221.0   800.0  train
# 3           Bandra West     4.1   24.0   800.0  train
# 4           Lower Parel     3.8  165.0   300.0  train
# ...                 ...     ...    ...     ...    ...
# 16916      Punjabi Bagh     3.9  287.0     NaN   test
# 16917        HSR Layout     4.3  469.0     NaN   test
# 16918         Sector 86     3.7   53.0     NaN   test
# 16919             Kochi     0.0    NaN     NaN   test
# 16920  Perry Cross Road     3.7   63.0     NaN   test
#
# [16921 rows x 10 columns]>

# %%
df_food["VOTES"]
# Out:
# 0         49.0
# 1         30.0
# 2        221.0
# 3         24.0
# 4        165.0
#          ...
# 16916    287.0
# 16917    469.0
# 16918     53.0
# 16919      NaN
# 16920     63.0
# Name: VOTES, Length: 16921, dtype: float64

# %%
df_food['VOTES'].fillna("Unknown",inplace=True)
df_food["VOTES"].replace("Unknown",0,inplace=True)
df_food["VOTES"]=df_food["VOTES"].astype(int)
df_food["VOTES"]
# Out:
# 0         49
# 1         30
# 2        221
# 3         24
# 4        165
#         ...
# 16916    287
# 16917    469
# 16918     53
# 16919      0
# 16920     63
# Name: VOTES, Length: 16921, dtype: int32

# %%
df_food.loc[df_food["VOTES"].isnull()]
# Out:
# Empty DataFrame
# Columns: [TITLE, RESTAURANT_ID, CUISINES, TIME, CITY, LOCALITY, RATING, VOTES, COST, source]
# Index: []

# %%
df_food.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY                0
# LOCALITY            0
# RATING              0
# VOTES               0
# COST             4231
# source              0
# dtype: int64

# %%
#Dropping TIME column
df_food.drop(columns=["TIME"],inplace=True)

# %%
df_food
# Out:
#                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 16916      CASUAL DINING           9057
# 16917               None           1247
# 16918        QUICK BITES           8617
# 16919        QUICK BITES           6485
# 16920        QUICK BITES           2421
#
#                                             CUISINES         CITY  \
# 0                        Malwani, Goan, North Indian        Thane
# 1                     Asian, Modern Indian, Japanese      Chennai
# 2         North Indian, Chinese, Biryani, Hyderabadi      Chennai
# 3                                   Tibetan, Chinese       Mumbai
# 4                                           Desserts       Mumbai
# ...                                              ...          ...
# 16916                 North Indian, Mughlai, Chinese    New Delhi
# 16917  Biryani, North Indian, Sandwich, Salad, Wraps    Bangalore
# 16918                      Continental, North Indian    Faridabad
# 16919                               Rolls, Beverages        Kochi
# 16920                                        Mughlai  Bandra West
#
#                LOCALITY  RATING  VOTES    COST source
# 0        Dombivali East     3.6     49  1200.0  train
# 1             Ramapuram     4.2     30  1500.0  train
# 2            Saligramam     3.8    221   800.0  train
# 3           Bandra West     4.1     24   800.0  train
# 4           Lower Parel     3.8    165   300.0  train
# ...                 ...     ...    ...     ...    ...
# 16916      Punjabi Bagh     3.9    287     NaN   test
# 16917        HSR Layout     4.3    469     NaN   test
# 16918         Sector 86     3.7     53     NaN   test
# 16919             Kochi     0.0      0     NaN   test
# 16920  Perry Cross Road     3.7     63     NaN   test
#
# [16921 rows x 9 columns]

# %%
#Divide the CUISINES column into columns
#Find maximum number of cuisines resutarnt are serving
max_cuisines=-1
for i in range(len(df_food["CUISINES"])):
    temp=len(df_food["CUISINES"].iloc[i].split(","))
    if temp>max_cuisines:
        max_cuisines=temp
print("Max number of CUISINES available are :{}".format(max_cuisines))
# Out:
# Max number of CUISINES available are :8

# %%
cu1=list()
cu2=list()
cu3=list()
cu4=list()
cu5=list()
cu6=list()
cu7=list()
cu8=list()
for i in range(len(df_food["CUISINES"])):
    temp=df_food["CUISINES"].iloc[i].split(",")
    try :
        cu1.append(temp[0].strip().upper())
    except :
        cu1.append('NONE')
    try :
        cu2.append(temp[1].strip().upper())
    except :
        cu2.append('NONE')
    try :
        cu3.append(temp[2].strip().upper())
    except :
        cu3.append('NONE')
    try :
        cu4.append(temp[3].strip().upper())
    except :
        cu4.append('NONE')
    try :
        cu5.append(temp[4].strip().upper())
    except :
        cu5.append('NONE')
    try :
        cu6.append(temp[5].strip().upper())
    except :
        cu6.append('NONE')
    try :
        cu7.append(temp[6].strip().upper())
    except :
        cu7.append('NONE')
    try :
        cu8.append(temp[7].strip().upper())
    except :
        cu8.append('NONE')

# %%
df_food["cu1"]=cu1
df_food["cu2"]=cu2
df_food["cu3"]=cu3
df_food["cu4"]=cu4
df_food["cu5"]=cu5
df_food["cu6"]=cu6
df_food["cu7"]=cu7
df_food["cu8"]=cu8

# %%
#Same way we will do for TITLE
max_titles=-1
for i in range(len(df_food["TITLE"])):
    temp=len(df_food["TITLE"].iloc[i].split(","))
    if temp>max_titles:
        max_titles=temp
print("Max number of TITLE are :{}".format(max_titles))
# Out:
# Max number of TITLE are :2

# %%
t1=list()
t2=list()
for i in range(len(df_food["TITLE"])):
    temp=df_food["TITLE"].iloc[i].split(",")
    try :
        t1.append(temp[0].strip().upper())
    except :
        t1.append('NONE')
    try :
        t2.append(temp[1].strip().upper())
    except :
        t2.append('NONE')

# %%
df_food["t1"]=t1
df_food["t2"]=t2

# %%
df_food
# Out:
#                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 16916      CASUAL DINING           9057
# 16917               None           1247
# 16918        QUICK BITES           8617
# 16919        QUICK BITES           6485
# 16920        QUICK BITES           2421
#
#                                             CUISINES         CITY  \
# 0                        Malwani, Goan, North Indian        Thane
# 1                     Asian, Modern Indian, Japanese      Chennai
# 2         North Indian, Chinese, Biryani, Hyderabadi      Chennai
# 3                                   Tibetan, Chinese       Mumbai
# 4                                           Desserts       Mumbai
# ...                                              ...          ...
# 16916                 North Indian, Mughlai, Chinese    New Delhi
# 16917  Biryani, North Indian, Sandwich, Salad, Wraps    Bangalore
# 16918                      Continental, North Indian    Faridabad
# 16919                               Rolls, Beverages        Kochi
# 16920                                        Mughlai  Bandra West
#
#                LOCALITY  RATING  VOTES    COST source           cu1  \
# 0        Dombivali East     3.6     49  1200.0  train       MALWANI
# 1             Ramapuram     4.2     30  1500.0  train         ASIAN
# 2            Saligramam     3.8    221   800.0  train  NORTH INDIAN
# 3           Bandra West     4.1     24   800.0  train       TIBETAN
# 4           Lower Parel     3.8    165   300.0  train      DESSERTS
# ...                 ...     ...    ...     ...    ...           ...
# 16916      Punjabi Bagh     3.9    287     NaN   test  NORTH INDIAN
# 16917        HSR Layout     4.3    469     NaN   test       BIRYANI
# 16918         Sector 86     3.7     53     NaN   test   CONTINENTAL
# 16919             Kochi     0.0      0     NaN   test         ROLLS
# 16920  Perry Cross Road     3.7     63     NaN   test       MUGHLAI
#
#                  cu2           cu3         cu4    cu5   cu6   cu7   cu8  \
# 0               GOAN  NORTH INDIAN        NONE   NONE  NONE  NONE  NONE
# 1      MODERN INDIAN      JAPANESE        NONE   NONE  NONE  NONE  NONE
# 2            CHINESE       BIRYANI  HYDERABADI   NONE  NONE  NONE  NONE
# 3            CHINESE          NONE        NONE   NONE  NONE  NONE  NONE
# 4               NONE          NONE        NONE   NONE  NONE  NONE  NONE
# ...              ...           ...         ...    ...   ...   ...   ...
# 16916        MUGHLAI       CHINESE        NONE   NONE  NONE  NONE  NONE
# 16917   NORTH INDIAN      SANDWICH       SALAD  WRAPS  NONE  NONE  NONE
# 16918   NORTH INDIAN          NONE        NONE   NONE  NONE  NONE  NONE
# 16919      BEVERAGES          NONE        NONE   NONE  NONE  NONE  NONE
# 16920           NONE          NONE        NONE   NONE  NONE  NONE  NONE
#
#                    t1    t2
# 0       CASUAL DINING  NONE
# 1       CASUAL DINING   BAR
# 2       CASUAL DINING  NONE
# 3         QUICK BITES  NONE
# 4      DESSERT PARLOR  NONE
# ...               ...   ...
# 16916   CASUAL DINING  NONE
# 16917            NONE  NONE
# 16918     QUICK BITES  NONE
# 16919     QUICK BITES  NONE
# 16920     QUICK BITES  NONE
#
# [16921 rows x 19 columns]

# %%
#We can Drop "CUISINES","TITLE","RESTAURANT_ID" column
df_food.drop(columns=["CUISINES","TITLE","RESTAURANT_ID"],inplace=True)

# %%
df_food
# Out:
#               CITY          LOCALITY  RATING  VOTES    COST source  \
# 0            Thane    Dombivali East     3.6     49  1200.0  train
# 1          Chennai         Ramapuram     4.2     30  1500.0  train
# 2          Chennai        Saligramam     3.8    221   800.0  train
# 3           Mumbai       Bandra West     4.1     24   800.0  train
# 4           Mumbai       Lower Parel     3.8    165   300.0  train
# ...            ...               ...     ...    ...     ...    ...
# 16916    New Delhi      Punjabi Bagh     3.9    287     NaN   test
# 16917    Bangalore        HSR Layout     4.3    469     NaN   test
# 16918    Faridabad         Sector 86     3.7     53     NaN   test
# 16919        Kochi             Kochi     0.0      0     NaN   test
# 16920  Bandra West  Perry Cross Road     3.7     63     NaN   test
#
#                 cu1            cu2           cu3         cu4    cu5   cu6  \
# 0           MALWANI           GOAN  NORTH INDIAN        NONE   NONE  NONE
# 1             ASIAN  MODERN INDIAN      JAPANESE        NONE   NONE  NONE
# 2      NORTH INDIAN        CHINESE       BIRYANI  HYDERABADI   NONE  NONE
# 3           TIBETAN        CHINESE          NONE        NONE   NONE  NONE
# 4          DESSERTS           NONE          NONE        NONE   NONE  NONE
# ...             ...            ...           ...         ...    ...   ...
# 16916  NORTH INDIAN        MUGHLAI       CHINESE        NONE   NONE  NONE
# 16917       BIRYANI   NORTH INDIAN      SANDWICH       SALAD  WRAPS  NONE
# 16918   CONTINENTAL   NORTH INDIAN          NONE        NONE   NONE  NONE
# 16919         ROLLS      BEVERAGES          NONE        NONE   NONE  NONE
# 16920       MUGHLAI           NONE          NONE        NONE   NONE  NONE
#
#         cu7   cu8              t1    t2
# 0      NONE  NONE   CASUAL DINING  NONE
# 1      NONE  NONE   CASUAL DINING   BAR
# 2      NONE  NONE   CASUAL DINING  NONE
# 3      NONE  NONE     QUICK BITES  NONE
# 4      NONE  NONE  DESSERT PARLOR  NONE
# ...     ...   ...             ...   ...
# 16916  NONE  NONE   CASUAL DINING  NONE
# 16917  NONE  NONE            NONE  NONE
# 16918  NONE  NONE     QUICK BITES  NONE
# 16919  NONE  NONE     QUICK BITES  NONE
# 16920  NONE  NONE     QUICK BITES  NONE
#
# [16921 rows x 16 columns]

# %%
df_food["VOTES"]=df_food["VOTES"].astype(int)

# %%
df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16921 entries, 0 to 16920
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CITY      16921 non-null  object
#  1   LOCALITY  16921 non-null  object
#  2   RATING    16921 non-null  float64
#  3   VOTES     16921 non-null  int32
#  4   COST      12690 non-null  float64
#  5   source    16921 non-null  object
#  6   cu1       16921 non-null  object
#  7   cu2       16921 non-null  object
#  8   cu3       16921 non-null  object
#  9   cu4       16921 non-null  object
#  10  cu5       16921 non-null  object
#  11  cu6       16921 non-null  object
#  12  cu7       16921 non-null  object
#  13  cu8       16921 non-null  object
#  14  t1        16921 non-null  object
#  15  t2        16921 non-null  object
# dtypes: float64(2), int32(1), object(13)
# memory usage: 2.0+ MB

# %%
from sklearn.preprocessing import LabelEncoder
for col in df_food.columns:
    if df_food[col].dtype=="object":
        df_food[col]=LabelEncoder().fit_transform(df_food[col])

# %%
#Displaying the dataset
df_food
# Out:
#        CITY  LOCALITY  RATING  VOTES    COST  source  cu1  cu2  cu3  cu4  cu5  \
# 0       400       328     3.6     49  1200.0       1   61   32   72   64   62
# 1        75      1214     4.2     30  1500.0       1    6   62   45   64   62
# 2        75      1272     3.8    221   800.0       1   74   23   14   34   62
# 3       277       161     4.1     24   800.0       1  102   23   70   64   62
# 4       277       709     3.8    165   300.0       1   30   67   70   64   62
# ...     ...       ...     ...    ...     ...     ...  ...  ...  ...  ...  ...
# 16916   316      1184     3.9    287     NaN       0   74   64   23   64   62
# 16917    42       461     4.3    469     NaN       0   15   69   83   73   83
# 16918   128      1370     3.7     53     NaN       0   29   69   70   64   62
# 16919   216       642     0.0      0     NaN       0   84   12   70   64   62
# 16920    40      1148     3.7     63     NaN       0   69   67   70   64   62
#
#        cu6  cu7  cu8  t1  t2
# 0       50   41   18   5  16
# 1       50   41   18   5   1
# 2       50   41   18   5  16
# 3       50   41   18  23  16
# 4       50   41   18   9  16
# ...    ...  ...  ...  ..  ..
# 16916   50   41   18   5  16
# 16917   50   41   18  20  16
# 16918   50   41   18  23  16
# 16919   50   41   18  23  16
# 16920   50   41   18  23  16
#
# [16921 rows x 16 columns]

# %%
#Lets chcek the datatypes
df_food.dtypes
# Out:
# CITY          int32
# LOCALITY      int32
# RATING      float64
# VOTES         int32
# COST        float64
# source        int32
# cu1           int32
# cu2           int32
# cu3           int32
# cu4           int32
# cu5           int32
# cu6           int32
# cu7           int32
# cu8           int32
# t1            int32
# t2            int32
# dtype: object

# %%
#Again we can split and Train Data
df_train=df_food.loc[df_food["source"]==1]
df_test=df_food.loc[df_food["source"]==0]

# %%
#Resetting the index
df_test.reset_index(drop=True,inplace=True)

# %%
#Dropping the source column
df_train.drop(columns=["source"],inplace=True)
df_test.drop(columns=["source"],inplace=True)
# Out:
# C:\Users\saran\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#Lets seprate the input and output from train dataset
df_x=df_train.drop(columns=["COST"])
y=df_train[["COST"]]

# %%
#to find random stat which gives maximum r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,df_x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
#Lets use decision tree
from sklearn.tree import DecisionTreeRegressor
import numpy as np
dtr=DecisionTreeRegressor()
r_state=maxr2_score(dtr,df_x,y)
# Out:
# r2 score corresponding to  42  is  0.37348940539064346
# r2 score corresponding to  43  is  0.4876542965985391
# r2 score corresponding to  44  is  0.4211259659102571
# r2 score corresponding to  45  is  0.44188492497855336
# r2 score corresponding to  46  is  0.4399438240669177
# r2 score corresponding to  47  is  0.5351458400426126
# r2 score corresponding to  48  is  0.19540269483826955
# r2 score corresponding to  49  is  0.45339646529677724
# r2 score corresponding to  50  is  0.09360745636045542
# r2 score corresponding to  51  is  0.4583728008215222
# r2 score corresponding to  52  is  0.36267761239410545
# r2 score corresponding to  53  is  0.5122632718819926
# r2 score corresponding to  54  is  0.3988988273791163
# r2 score corresponding to  55  is  0.45129278511546556
# r2 score corresponding to  56  is  0.5181333344873341
# r2 score corresponding to  57  is  0.4413470914538984
# r2 score corresponding to  58  is  0.43676183957913584
# r2 score corresponding to  59  is  0.4201709791994752
# r2 score corresponding to  60  is  0.37544124862241135
# r2 score corresponding to  61  is  0.47851492056051936
# r2 score corresponding to  62  is  0.396590593362421
# r2 score corresponding to  63  is  0.29286802242273
# r2 score corresponding to  64  is  0.4526943634495145
# r2 score corresponding to  65  is  0.19807147611843323
# r2 score corresponding to  66  is  0.3653479581839566
# r2 score corresponding to  67  is  0.4128425479397275
# r2 score corresponding to  68  is  0.44867785059153054
# r2 score corresponding to  69  is  0.5179272281139911
# r2 score corresponding to  70  is  0.43140112962437416
# r2 score corresponding to  71  is  0.4788966311029662
# r2 score corresponding to  72  is  0.3585459696616684
# r2 score corresponding to  73  is  0.18124246512155728
# r2 score corresponding to  74  is  0.46265654874655326
# r2 score corresponding to  75  is  0.5053231155170816
# r2 score corresponding to  76  is  0.5038795782787463
# r2 score corresponding to  77  is  0.5188169687438361
# r2 score corresponding to  78  is  0.4595725804530849
# r2 score corresponding to  79  is  0.11867980326775163
# r2 score corresponding to  80  is  0.5396832210866055
# r2 score corresponding to  81  is  0.5129049083588042
# r2 score corresponding to  82  is  0.4101478105892221
# r2 score corresponding to  83  is  0.38797561922083423
# r2 score corresponding to  84  is  0.30192046470979383
# r2 score corresponding to  85  is  0.4213877472229224
# r2 score corresponding to  86  is  0.5054698895224146
# r2 score corresponding to  87  is  0.2208996925026252
# r2 score corresponding to  88  is  0.5041350092725743
# r2 score corresponding to  89  is  0.4651086302462568
# r2 score corresponding to  90  is  0.4310697504154285
# r2 score corresponding to  91  is  0.4257963629225523
# r2 score corresponding to  92  is  0.19366408423830672
# r2 score corresponding to  93  is  0.5722982602897837
# r2 score corresponding to  94  is  0.3241986848102818
# r2 score corresponding to  95  is  0.44366770532254807
# r2 score corresponding to  96  is  0.4561657806681414
# r2 score corresponding to  97  is  0.378972354706514
# r2 score corresponding to  98  is  0.4592678132107222
# r2 score corresponding to  99  is  0.4517823766221637
# max r2 score corresponding to  93  is  0.5722982602897837

# %%
#lets use random forest regressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore")
rfr=RandomForestRegressor()
parameters = {"n_estimators":[10,100,500]}
clf = GridSearchCV(rfr, parameters, cv=5,scoring="r2")
clf.fit(df_x,y)
clf.best_params_
# Out:
# {'n_estimators': 500}

# %%
rfr=RandomForestRegressor(n_estimators=500)
r_state=maxr2_score(rfr,df_x,y)
# Out:
# r2 score corresponding to  42  is  0.7348275451992585
# r2 score corresponding to  43  is  0.7472503316582386
# r2 score corresponding to  44  is  0.7158384691586615
# r2 score corresponding to  45  is  0.6969790523373307
# r2 score corresponding to  46  is  0.7365914413981016
# r2 score corresponding to  47  is  0.713671768781488
# r2 score corresponding to  48  is  0.6171083016240546
# r2 score corresponding to  49  is  0.6415601711017097
# r2 score corresponding to  50  is  0.7089085174994225
# r2 score corresponding to  51  is  0.7266300309040131
# r2 score corresponding to  52  is  0.621371660993459
# r2 score corresponding to  53  is  0.7247937377326572
# r2 score corresponding to  54  is  0.6912749480449897
# r2 score corresponding to  55  is  0.7497880394776908
# r2 score corresponding to  56  is  0.7234393699329216
# r2 score corresponding to  57  is  0.6868923044095672
# r2 score corresponding to  58  is  0.6302997959218952
# r2 score corresponding to  59  is  0.7235967899614624
# r2 score corresponding to  60  is  0.7379410498802991
# r2 score corresponding to  61  is  0.6898469748658447
# r2 score corresponding to  62  is  0.6300140052929379
# r2 score corresponding to  63  is  0.7145708384355385
# r2 score corresponding to  64  is  0.6697437002141767
# r2 score corresponding to  65  is  0.6930412928739788
# r2 score corresponding to  66  is  0.7237005475346692
# r2 score corresponding to  67  is  0.6833434485035645
# r2 score corresponding to  68  is  0.7239986200545216
# r2 score corresponding to  69  is  0.6582530046060504
# r2 score corresponding to  70  is  0.7310124231867581
# r2 score corresponding to  71  is  0.7376185619374067
# r2 score corresponding to  72  is  0.738918991520757
# r2 score corresponding to  73  is  0.6717391361224265
# r2 score corresponding to  74  is  0.7448418949547321
# r2 score corresponding to  75  is  0.6864472584354866
# r2 score corresponding to  76  is  0.7453224742502631
# r2 score corresponding to  77  is  0.7519894533325744
# r2 score corresponding to  78  is  0.6639888994904828
# r2 score corresponding to  79  is  0.7326124945477539
# r2 score corresponding to  80  is  0.7205968443592428
# r2 score corresponding to  81  is  0.7224828503805776
# r2 score corresponding to  82  is  0.7123327939046762
# r2 score corresponding to  83  is  0.6566287571568139
# r2 score corresponding to  84  is  0.7288308132325341
# r2 score corresponding to  85  is  0.7061976649622521
# r2 score corresponding to  86  is  0.7232742032933024
# r2 score corresponding to  87  is  0.7104325826502346
# r2 score corresponding to  88  is  0.7240184643772478
# r2 score corresponding to  89  is  0.7057253113243047
# r2 score corresponding to  90  is  0.7272812133082147
# r2 score corresponding to  91  is  0.7299649589816899
# r2 score corresponding to  92  is  0.7145268134513725
# r2 score corresponding to  93  is  0.7351900378470153
# r2 score corresponding to  94  is  0.7322370008520259
# r2 score corresponding to  95  is  0.7080182310558094
# r2 score corresponding to  96  is  0.6448596361877214
# r2 score corresponding to  97  is  0.6275146079471976
# r2 score corresponding to  98  is  0.7038713619198966
# r2 score corresponding to  99  is  0.706704724942909
# max r2 score corresponding to  77  is  0.7519894533325744

# %%
import lightgbm as lgb
lg = lgb.LGBMRegressor(silent=False)
param_dist = {"max_depth": [25,50, 75],
              "learning_rate" : [0.01,0.05,0.1],
              "num_leaves": [300,900,1200],
              "n_estimators": [200]
             }
grid_search = GridSearchCV(lg, n_jobs=-1, param_grid=param_dist, cv = 5, scoring="r2")
grid_search.fit(df_x,y)
grid_search.best_estimator_
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002756 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 12690, number of used features: 14
# [LightGBM] [Info] Start training from score 655.252246
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor(learning_rate=0.05, max_depth=25, n_estimators=200,
#               num_leaves=300, silent=False)

# %%
lgbr=lgb.LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
       importance_type='split', learning_rate=0.05, max_depth=25,
       min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
       n_estimators=200, n_jobs=-1, num_leaves=900, objective=None,
       random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=False,
       subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
r_state=maxr2_score(lgbr,df_x,y)
#Here we see that lightfbm was faster and better than random forest
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001365 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1236
# [LightGBM] [Info] Number of data points in the train set: 10152, number of used features: 14
# [LightGBM] [Info] Start training from score 659.003940
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# r2 score corresponding to  42  is  0.741622800160419
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000934 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1233
# [LightGBM] [Info] Number of data points in the train set: 10152, number of used features: 14
# [LightGBM] [Info] Start training from score 656.597813
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# r2 score corresponding to  43  is  0.7529037921968
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000985 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1219
# [LightGBM] [Info] Number of data points in the train set: 10152, number of used features: 14
# [LightGBM] [Info] Start training from score 658.378743
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# r2 score corresponding to  44  is  0.7222848457003598
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000947 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1228
# [LightGBM] [Info] Number of data points in the train set: 10152, number of used features: 14
# [LightGBM] [Info] Start training from score 655.171592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# r2 score corresponding to  66  is  0.7123496514386545
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002213 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1225
# [LightGBM] [Info] Number of data points in the train set: 10152, number of used features: 14
# [LightGBM] [Info] Start training from score 655.433511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
grid_search.best_params_

# %%
#LGBM also give provision to define which all columns should be treated as categorical
#So we will use above provision and see what is the result
params={'learning_rate': 0.05,'max_depth': 25,'n_estimators': 200,'num_leaves': 900}
cate_features_name=['CITY', 'LOCALITY', 'c1', 'c2', 'c3', 'c4', 'c5','c6', 'c7', 'c8', 't1', 't2']
max_r_score=0
for r_state in range(42,100):
    x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = r_state,test_size=0.20)
    d_train = lgb.Dataset(x_train, label=y_train)
    lgb_model = lgb.train(params, d_train, categorical_feature = cate_features_name)
    y_pred = lgb_model.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print("r2 score corresponding to ",r_state," is ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to ",final_r_state," is ",max_r_score)

# %%
#lets make a function which evaluates the model using cross_val_score
from sklearn.model_selection import cross_val_score
def model_evaluation(model,x,y):
    c_scores=cross_val_score(model,x,y,cv=5,scoring="r2")
    print("Mean r2 score for regressor: ",c_scores.mean())
    print("standard deviation in r2 score for regressor: ",c_scores.std())
    print(c_scores)

# %%
#The above model i.e light gradient boosting works better when categorical features are defined
#So we will use this to create our final model
#Also when compared to random forest its giving better and fast results
#Lets chcek the cross_val_scores
from sklearn.model_selection import KFold
scores=[]
cate_features_name=['CITY', 'LOCALITY', 'c1', 'c2', 'c3', 'c4', 'c5','c6', 'c7', 'c8', 't1', 't2']
k_fold = KFold(n_splits=5)
for train_index,test_index in k_fold.split(df_x):
    x_train, x_test, y_train, y_test = df_x.iloc[train_index], df_x.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    d_train = lgb.Dataset(x_train, label=y_train)
    lgb_model = lgb.train(params, d_train, categorical_feature = cate_features_name)
    y_pred = lgb_model.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    scores.append(r2_scr)
print("Mean r2 score for lgbm regressor: ",np.array(scores).mean())
print("standard deviation in r2 score for lgbm regressor: ",np.array(scores).std())
print(scores)

# %%
#lets chcek for random forset
print("RANDOM FOREST\n\n")
model_evaluation(rfr,df_x,y)

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = 43,test_size=0.20)
d_train = lgb.Dataset(x_train, label=y_train)
lgb_model = lgb.train(params, d_train, categorical_feature = cate_features_name)
y_pred = lgb_model.predict(x_test)

# %%
#Lets find the rmse and r2_score using sklearn.metrics for random forest model
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score is: ",r2_score(y_test,y_pred))

# %%
#From above we see lgbm is performing better so we will use it to make our final predictions
cost_pred=lgb_model.predict(df_test)

# %%
#lets make the dataframe for cost_pred
cost_pred=pd.DataFrame(cost_pred,columns=["COST"])

# %%
#Lets save the submission to csv
cost_pred.to_csv("COST_Predictions.csv",index=False)
